# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# To avoid warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# develop a machine learning model to predict the price of residential properties in Bengaluru based on historical data

# %% [markdown]
# ### Key Challenges:
# 1. Handling Missing Data: Certain columns, such as society and balcony, contain missing values that need to be appropriately imputed or processed.
# 2. Feature Engineering: Columns like size and total_sqft might need preprocessing to create features that accurately represent the property size and layout.
# 3. Categorical Data: The society and area columns contain categorical data that will need to be encoded for model training.
# 4. Price Range Variability: The dataset may contain properties across a wide price range, which could make modeling more complex if certain areas have highly disparate price patterns.

# %% [markdown]
# ## Data Gathering

# %%
df = pd.read_csv("Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# ### Handeling Missing values

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df['society']
# Out:
# 0        Coomee
# 1        Theanmp
# 2            NaN
# 3        Soiewre
# 4            NaN
#           ...
# 13315    ArsiaEx
# 13316        NaN
# 13317    Mahla T
# 13318    SollyCl
# 13319        NaN
# Name: society, Length: 13320, dtype: object

# %%
df['society'].fillna("Unknown",inplace=True)

# %%
df['balcony'].fillna(df['balcony'].mean(), inplace=True)

# %%
df['bath'].fillna(df['bath'].mean(), inplace = True)

# %%
df['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
df['size'].fillna("2 BHK",inplace=True)

# %%
df['location'].fillna("Unknown",inplace=True)

# %%
df.isna().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath   balcony   price
# 0          2 BHK  Coomee        1056   2.0  1.000000   39.07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   size          13320 non-null  object
#  4   society       13320 non-null  object
#  5   total_sqft    13320 non-null  object
#  6   bath          13320 non-null  float64
#  7   balcony       13320 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %% [markdown]
# ### Cheacking outliers

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath   balcony   price
# 0          2 BHK  Coomee        1056   2.0  1.000000   39.07
# ...

# %% [markdown]
# #### Outliers Checking

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplot for each numeric column
plt.figure(figsize=(15, 8))
for i, col in enumerate(df.select_dtypes(include=[np.number]).columns, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(data=df, x=col)
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Function to detect outliers using IQR
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

# Detect outliers in each numeric column
for col in df.select_dtypes(include=[np.number]).columns:
    print(f"Outliers in {col}:")
    outliers = detect_outliers_iqr(df, col)
    print(outliers[col])
    print(f"Number of outliers: {outliers.shape[0]}")
    print("-" * 50)
# Out:
# Outliers in bath:
# 1        5.0
# 9        6.0
# 11       5.0
# 22       5.0
# 45       9.0
#         ...
# 13300    6.0
# 13303    5.0
# 13306    5.0
# 13311    9.0
# 13316    5.0
# Name: bath, Length: 1039, dtype: float64
# Number of outliers: 1039
# --------------------------------------------------
# Outliers in balcony:
# Series([], Name: balcony, dtype: float64)
# Number of outliers: 0
# --------------------------------------------------
# Outliers in price:
# 7        600.0
# 9        370.0
# 11       295.0
# 18       290.0
# 22       380.0
#          ...
# 13306    325.0
# 13311    250.0
# 13315    231.0
# 13316    400.0
# 13318    488.0
# Name: price, Length: 1276, dtype: float64
# Number of outliers: 1276
# --------------------------------------------------

# %%
# Function to detect and impute outliers with the median
def impute_outliers_with_median(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Impute outliers with median
    median_value = data[column].median()
    data.loc[(data[column] < lower_bound) | (data[column] > upper_bound), column] = median_value

# Apply the function to each numeric column
for col in df.select_dtypes(include=[np.number]).columns:
    impute_outliers_with_median(df, col)

# %%
# Check for remaining outliers
for col in df.select_dtypes(include=[np.number]).columns:
    print(f"Outliers in {col} after imputation:")
    print(detect_outliers_iqr(df, col))
# Out:
# Outliers in bath after imputation:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price]
# Index: []
# Outliers in balcony after imputation:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price]
# Index: []
# Outliers in price after imputation:
#                   area_type   availability               location       size  \
# 6      Super built-up  Area         18-May       Old Airport Road      4 BHK
# 30     Super built-up  Area         19-Dec              Yelahanka      4 BHK
# 45               Plot  Area  Ready To Move             HSR Layout  8 Bedroom
# 56           Built-up  Area         20-Feb            Devanahalli  4 Bedroom
# 57     Super built-up  Area  Ready To Move  Ramakrishnappa Layout      2 BHK
# ...                     ...            ...                    ...        ...
# ...

# %%
plt.figure(figsize=(15, 8))
for i, col in enumerate(df.select_dtypes(include=[np.number]).columns, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(data=df, x=col)
    plt.title(f'Box Plot of {col} (After Imputation)')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath   balcony   price
# 0          2 BHK  Coomee        1056   2.0  1.000000   39.07
# ...

# %%
df.columns
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   2.0      3.0  120.00
# 2  Unknown       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4  Unknown       1200   2.0      1.0   51.00

# %% [markdown]
# ### Use of One hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
categorical_features = df.select_dtypes(include=['object']).columns
categorical_features
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft'],
#       dtype='object')

# %%
num_unique_area_type = df['area_type'].nunique()
# Print the result
print(f"Number of unique values in 'area_type': {num_unique_area_type}")


num_unique_area_type = df['availability'].nunique()
# Print the result
print(f"Number of unique values in 'availability': {num_unique_area_type}")

num_unique_area_type = df['location'].nunique()

# Print the result
print(f"Number of unique values in 'location': {num_unique_area_type}")


num_unique_area_type = df['size'].nunique()
# Print the result
print(f"Number of unique values in 'size': {num_unique_area_type}")

num_unique_area_type = df['society'].nunique()
# Print the result
print(f"Number of unique values in 'society': {num_unique_area_type}")
# Out:
# Number of unique values in 'area_type': 4
# Number of unique values in 'availability': 81
# Number of unique values in 'location': 1305
# Number of unique values in 'size': 31
# Number of unique values in 'society': 2688

# %%
df['area_type'].value_counts().to_dict()
# Out:
# {'Super built-up  Area': 8790,
#  'Built-up  Area': 2418,
#  'Plot  Area': 2025,
#  'Carpet  Area': 87}

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# use One hot encoding

df = pd.get_dummies(df, columns=['area_type'], dtype=int)

# Display the updated DataFrame
print(df.head())
# Out:
#     availability                  location       size  society total_sqft  \
# 0         19-Dec  Electronic City Phase II      2 BHK  Coomee        1056
# 1  Ready To Move          Chikka Tirupathi  4 Bedroom  Theanmp       2600
# 2  Ready To Move               Uttarahalli      3 BHK      NaN       1440
# 3  Ready To Move        Lingadheeranahalli      3 BHK  Soiewre       1521
# 4  Ready To Move                  Kothanur      2 BHK      NaN       1200
#
#    bath  balcony   price  area_type_Built-up  Area  area_type_Carpet  Area  \
# 0   2.0      1.0   39.07                         0                       0
# 1   5.0      3.0  120.00                         0                       0
# 2   2.0      3.0   62.00                         1                       0
# 3   3.0      1.0   95.00                         0                       0
# 4   2.0      1.0   51.00                         0                       0
#
#    area_type_Plot  Area  area_type_Super built-up  Area
# ...

# %%
#frequency encoding on location column
freq_encoding = df['location'].value_counts().to_dict()
df['location'] = df['location'].map(freq_encoding)

print(df.head())
# Out:
#     availability  location       size  society total_sqft  bath  balcony  \
# 0         19-Dec     132.0      2 BHK  Coomee        1056   2.0      1.0
# 1  Ready To Move      17.0  4 Bedroom  Theanmp       2600   5.0      3.0
# 2  Ready To Move     186.0      3 BHK      NaN       1440   2.0      3.0
# 3  Ready To Move      23.0      3 BHK  Soiewre       1521   3.0      1.0
# 4  Ready To Move      66.0      2 BHK      NaN       1200   2.0      1.0
#
#     price  area_type_Built-up  Area  area_type_Carpet  Area  \
# 0   39.07                         0                       0
# 1  120.00                         0                       0
# 2   62.00                         1                       0
# 3   95.00                         0                       0
# 4   51.00                         0                       0
#
#    area_type_Plot  Area  area_type_Super built-up  Area
# 0                     0                               1
# ...

# %%
#label encoding on size column
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['size'] = le.fit_transform(df['size'])

print(df.head())
# Out:
#     availability  location  size  society total_sqft  bath  balcony   price  \
# 0         19-Dec     132.0    13  Coomee        1056   2.0      1.0   39.07
# 1  Ready To Move      17.0    19  Theanmp       2600   5.0      3.0  120.00
# 2  Ready To Move     186.0    16      NaN       1440   2.0      3.0   62.00
# 3  Ready To Move      23.0    16  Soiewre       1521   3.0      1.0   95.00
# 4  Ready To Move      66.0    13      NaN       1200   2.0      1.0   51.00
#
#    area_type_Built-up  Area  area_type_Carpet  Area  area_type_Plot  Area  \
# 0                         0                       0                     0
# 1                         0                       0                     1
# 2                         1                       0                     0
# 3                         0                       0                     0
# 4                         0                       0                     0
#
#    area_type_Super built-up  Area
# ...

# %%
#frequency encoding on society column
freq_encoding = df['society'].value_counts().to_dict()
df['society'] = df['society'].map(freq_encoding)

print(df.head())
# Out:
#     availability  location  size  society total_sqft  bath  balcony   price  \
# 0         19-Dec     132.0    13      5.0       1056   2.0      1.0   39.07
# 1  Ready To Move      17.0    19     13.0       2600   5.0      3.0  120.00
# 2  Ready To Move     186.0    16      NaN       1440   2.0      3.0   62.00
# 3  Ready To Move      23.0    16     22.0       1521   3.0      1.0   95.00
# 4  Ready To Move      66.0    13      NaN       1200   2.0      1.0   51.00
#
#    area_type_Built-up  Area  area_type_Carpet  Area  area_type_Plot  Area  \
# 0                         0                       0                     0
# 1                         0                       0                     1
# 2                         1                       0                     0
# 3                         0                       0                     0
# 4                         0                       0                     0
#
#    area_type_Super built-up  Area
# ...

# %%
df
# Out:
#         availability  location  size  society total_sqft  bath  balcony  \
# 0             19-Dec     132.0    13      5.0       1056   2.0      1.0
# 1      Ready To Move      17.0    19     13.0       2600   5.0      3.0
# 2      Ready To Move     186.0    16      NaN       1440   2.0      3.0
# 3      Ready To Move      23.0    16     22.0       1521   3.0      1.0
# 4      Ready To Move      66.0    13      NaN       1200   2.0      1.0
# ...              ...       ...   ...      ...        ...   ...      ...
# 13315  Ready To Move     540.0    22      5.0       3453   4.0      0.0
# 13316  Ready To Move       7.0    18      NaN       3600   5.0      NaN
# 13317  Ready To Move     171.0    13      2.0       1141   2.0      1.0
# 13318         18-Jun      28.0    18      3.0       4689   4.0      1.0
# 13319  Ready To Move      30.0     0      NaN        550   1.0      1.0
#
#         price  area_type_Built-up  Area  area_type_Carpet  Area  \
# ...

# %%
df.isna().sum()
# Out:
# availability                         0
# location                             1
# size                                 0
# society                           5502
# total_sqft                           0
# bath                                73
# balcony                            609
# price                                0
# area_type_Built-up  Area             0
# area_type_Carpet  Area               0
# area_type_Plot  Area                 0
# area_type_Super built-up  Area       0
# dtype: int64

# %%
df['society'].fillna(0,inplace=True)

# %%
df['bath'].fillna(0,inplace=True)

# %%
df['balcony'].fillna(0,inplace=True)

# %%
df['location'].fillna(0,inplace=True)

# %%
df.isna().sum()
# Out:
# availability                      0
# location                          0
# size                              0
# society                           0
# total_sqft                        0
# bath                              0
# balcony                           0
# price                             0
# area_type_Built-up  Area          0
# area_type_Carpet  Area            0
# area_type_Plot  Area              0
# area_type_Super built-up  Area    0
# dtype: int64

# %% [markdown]
# ### Train test Split

# %%
df = df.select_dtypes(exclude=object)

x = df.drop("price", axis = 1)
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=25)

# %%
x_train
# Out:
#        location  size  society  bath  balcony  area_type_Built-up  Area  \
# 3779       36.0    13     27.0   2.0      2.0                         0
# 8914      149.0    16     14.0   3.0      2.0                         0
# 6610       36.0    18      2.0   5.0      3.0                         0
# 7275      399.0    13     37.0   2.0      2.0                         0
# 9821      399.0    17      0.0   3.0      1.0                         0
# ...         ...   ...      ...   ...      ...                       ...
# 8447       24.0    16      3.0   3.0      3.0                         0
# 2934       85.0    13      5.0   2.0      2.0                         0
# 10383     399.0    16     12.0   3.0      2.0                         0
# 6618      399.0    16      4.0   3.0      0.0                         0
# 8510      171.0    13     80.0   2.0      2.0                         1
#
#        area_type_Carpet  Area  area_type_Plot  Area  \
# ...

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (10656, 9)
# x_test shape: (2664, 9)
# y_train shape: (10656,)
# y_test shape: (2664,)

# %%
df.shape
# Out:
# (13320, 10)

# %%
# Testing Dataset
y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
print("MSE :",mse)

rmse = np.sqrt(mse)
print("RMSE :",rmse)

mae = mean_absolute_error(y_test, y_pred)
print("MAE :",mae)

r2 = r2_score(y_test, y_pred)
print("R Squared :",r2)
# Out:
# MSE : 11612.171955664813
# RMSE : 107.75978821278748
# MAE : 53.75886181389429
# R Squared : 0.2409169213586746

# %%
# training Data Set
y_pred_train = model.predict(x_train)

mse = mean_squared_error(y_train, y_pred_train)
print("MSE :",mse)

rmse = np.sqrt(mse)
print("RMSE :",rmse)

mae = mean_absolute_error(y_train, y_pred_train)
print("MAE :",mae)

r2 = r2_score(y_train, y_pred_train)
print("R Squared :",r2)
# Out:
# MSE : 18872.28009991178
# RMSE : 137.3764175537846
# MAE : 56.58764551049382
# R Squared : 0.21075277659239033

# %%
from sklearn.feature_selection import SelectKBest, f_regression
selector = SelectKBest(score_func=f_regression, k='all')
x_new = selector.fit_transform(x, y)
selected_features = x.columns[selector.get_support()]
print("Selected Features:", selected_features)
# Out:
# Selected Features: Index(['location', 'size', 'society', 'bath', 'balcony',
#        'area_type_Built-up  Area', 'area_type_Carpet  Area',
#        'area_type_Plot  Area', 'area_type_Super built-up  Area'],
#       dtype='object')

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, x, y, cv=10, scoring='r2')
print("Cross-Validation Scores:", scores)
print("Mean R2 Score:", scores.mean())
# Out:
# Cross-Validation Scores: [0.23577329 0.19327686 0.21708122 0.21036866 0.21814811 0.21014936
#  0.18986488 0.24030487 0.19122102 0.20168022]
# Mean R2 Score: 0.21078685068371555
